# %% [markdown]
# # 反爬：驗證碼處理
#
# * 了解「驗證碼機制」的反爬蟲機制
# * 「驗證碼機制」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 讀讀看「test」資料夾下的圖檔！
# * 像 test/test2.png 這種複雜的圖片怎麼辦？

# %% [markdown]
# ### 讀讀看「test」資料夾下的圖檔！

# %%
import requests
import pytesseract
from PIL import Image
from io import BytesIO

# Warnning : We must write this code
pytesseract.pytesseract.tesseract_cmd = 'C:\\Program Files (x86)\\Tesseract-OCR\\tesseract.exe'

# %%
# My code
img1 = Image.open('test1.png')
img1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=954x362 at 0x2524A12C4C8>

# %%
# My code

img1Str = pytesseract.image_to_string(img1)
print(img1Str)
# Out:
# 619121

# %% [markdown]
# ### 像 test/test2.png 這種複雜的圖片怎麼辦？
# - 做高斯模糊
# - 二值化
# - 形態學(侵蝕或膨脹)

# %%
img2 = Image.open("test2.png").convert("L")
img2
# Out:
# <PIL.Image.Image image mode=L size=154x64 at 0x2524A112FC8>

# %%
# My code

img2Str = pytesseract.image_to_string(img2)
print(img2Str)
# Out:
# 4413
